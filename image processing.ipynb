# %%
import PIL
from PIL import Image
from IPython.display import display
from PIL import ImageFilter
print("""welcome to this minor project on image manipulation and it is  made by abhay 
""")
file=input("upload the pic for editing :")
img= Image.open(file)
bl_img=img.filter(PIL.ImageFilter.BLUR)

bl_img1=img.filter(PIL.ImageFilter.CONTOUR)
bl_img2=img.filter(PIL.ImageFilter.DETAIL)
bl_img3=img.filter(PIL.ImageFilter.EDGE_ENHANCE)
bl_img4=img.filter(PIL.ImageFilter.FIND_EDGES)
bl_img5=img.filter(PIL.ImageFilter.SHARPEN)
bl_img6=img.filter(PIL.ImageFilter.SMOOTH)
bl_img7=img.filter(PIL.ImageFilter.SMOOTH_MORE)

display(bl_img,bl_img1,bl_img2,bl_img3,bl_img4,bl_img5,bl_img6,bl_img7)
# Out:
# welcome to this minor project on image manipulation and it is  made by abhay
#
# upload the pic for editing :IMG_20200318_215109.jpg
# <PIL.Image.Image image mode=RGB size=400x400 at 0x22ED34E3208>
# <PIL.Image.Image image mode=RGB size=400x400 at 0x22ED34E3188>
# <PIL.Image.Image image mode=RGB size=400x400 at 0x22ED34E3308>
# <PIL.Image.Image image mode=RGB size=400x400 at 0x22ED34E3388>
# <PIL.Image.Image image mode=RGB size=400x400 at 0x22ED34E3408>
# <PIL.Image.Image image mode=RGB size=400x400 at 0x22ED34E3488>
# <PIL.Image.Image image mode=RGB size=400x400 at 0x22ED34E3508>
# <PIL.Image.Image image mode=RGB size=400x400 at 0x22ED34E3588>

# %% [markdown]
# # I do some image manipulation task on given  image

# %%
import PIL
from PIL import Image
from PIL import ImageEnhance

# read image and convert to RGB
image=Image.open("IMG_20200318_215109.jpg")
image=image.convert('RGB')

# build a list of 9 images which have different brightnesses
enhancer=ImageEnhance.Brightness(image)
images=[]
for i in range(1, 10):
    images.append(enhancer.enhance(i/5))

# create a contact sheet from different brightnesses
first_image=images[0]
contact_sheet=PIL.Image.new(first_image.mode, (first_image.width*3,first_image.height*3))
x=0
y=0

for img in images:
    # Lets paste the current image into the contact sheet
    contact_sheet.paste(img, (x, y) )
    # Now we update our X position. If it is going to be the width of the image, then we set it to 0
    # and update Y as well to point to the next "line" of the contact sheet.
    if x+first_image.width == contact_sheet.width:
        x=0
        y=y+first_image.height
    else:
        x=x+first_image.width

# resize and display the contact sheet
contact_sheet = contact_sheet.resize((int(contact_sheet.width/2),int(contact_sheet.height/2) ))
display(contact_sheet)
# Out:
# <PIL.Image.Image image mode=RGB size=600x600 at 0x22ED1F27788>
